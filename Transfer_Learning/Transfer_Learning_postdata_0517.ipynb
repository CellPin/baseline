# %% [markdown]
# # 1006개의 데이터로 Transfer_Learning 하기
#
# - 논문의 모델에 1006개의 데이터를 넣고 학습을 시켜보자
#
# ## Step 1. 실험환경 set-up
#
# #### 라이브러리 실행

# %%
from tensorflow.keras             import utils, regularizers
from tensorflow.keras.models      import Sequential, load_model
from tensorflow.keras.layers      import Conv2D, MaxPooling2D, AveragePooling2D, Dense, Dropout, Activation, Flatten
from tensorflow.keras.optimizers  import Adam
from tensorflow.keras.constraints import MaxNorm
from sklearn.model_selection      import train_test_split  # 데이터 전처리에 필요한 패키지

import os                       # I/O 관련된 작업에 필요한 패키지 
import numpy             as np  # 데이터 array 작업에 필요한 패키지
import tensorflow        as tf  # 딥러닝 관련된 작업에 필요한 패키지
import matplotlib.pyplot as plt # 데이터 시각화에 관련된 작업에 필요한 패키지

import re    # 정규표현식 관련된 작업에 필요한 패키지
import os    # I/O 관련된 작업에 필요한 패키지 
import pandas as pd     # 데이터 전처리 관련된 작업에 필요한 패키지
import numpy as np      # 데이터 array 작업에 필요한 패키지
import tensorflow as tf  # 딥러닝 관련된 작업에 필요한 패키지
import matplotlib.pyplot as plt    # 데이터 시각화에 관련된 작업에 필요한 패키지
from sklearn.model_selection import train_test_split  # 데이터 전처리에 필요한 패키지
from PIL import Image

# %% [markdown]
# #### 필요한 변수들 생성

# %%
# 데이터 로드할 때 빠르게 로드할 수 있도록하는 설정 변수
AUTOTUNE = tf.data.experimental.AUTOTUNE

# BATCH_SIZE 변수
BATCH_SIZE = 32

# 이미지 사이즈 변수
IMAGE_SIZE = [1024, 1360]

# EPOCH 크기 변수
EPOCHS = 150

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'),
#  PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %% [markdown]
# ## Step 2. 데이터 준비하기
#
# 먼저 아래의 링크에서 데이터를 다운 받을 것
#
# https://drive.google.com/drive/folders/1Pi5qyX080zY2IdGT1TvvLraBO9DHBxJl?usp=sharing
#
# 받은 후 터미널 창에 아래의 명령어들을 차례로 입력
#
# ```
# $ cd ~/Downloads && cp CellPin ~/aiffel
# ```
#
# #### 데이터의 개수 확인

# %%
# 데이터 ROOT 경로 변수
ROOT_PATH = os.path.join(os.getenv('HOME'), 'cellpin/CellPin')
print(ROOT_PATH)

train_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/train/*/*'))
test_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/test/*/*'))
val_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/val/*/*'))

print(len(train_filenames))
print(len(test_filenames))
print(len(val_filenames))
# Out:
# /home/mochafreddo/cellpin/CellPin
# 782
# 104
# 126

# %% [markdown]
# #### train과 validation을 80:20으로 분할

# %%
# filenames = tf.io.gfile.glob(str(ROOT_PATH + '/train/*/*'))
# filenames.extend(tf.io.gfile.glob(str(ROOT_PATH + '/val/*/*')))

# train_filenames, val_filenames = train_test_split(filenames, test_size=0.2)

# print(len(train_filenames))
# print(len(val_filenames))

# %% [markdown]
# #### train 데이터 안에 정상 이미지 수와 CPE 이미지 수

# %%
COUNT_NORMAL = len([filename for filename in train_filenames if "normal" in filename])
print("NORMAL images count in training set: " + str(COUNT_NORMAL))

COUNT_CPE = len([filename for filename in train_filenames if "cpe" in filename])
print("CPE images count in training set: " + str(COUNT_CPE))
# Out:
# NORMAL images count in training set: 355
# CPE images count in training set: 427

# %% [markdown]
# #### val 데이터 안에 정상 이미지 수와 CPE 이미지 수

# %%
COUNT_NORMAL = len([filename for filename in val_filenames if "normal" in filename])
print("NORMAL images count in training set: " + str(COUNT_NORMAL))

COUNT_CPE = len([filename for filename in val_filenames if "cpe" in filename])
print("CPE images count in training set: " + str(COUNT_CPE))
# Out:
# NORMAL images count in training set: 50
# CPE images count in training set: 76

# %% [markdown]
# #### test 데이터 안에 정상 이미지 수와 CPE 이미지 수

# %%
COUNT_NORMAL = len([filename for filename in test_filenames if "normal" in filename])
print("NORMAL images count in training set: " + str(COUNT_NORMAL))

COUNT_CPE = len([filename for filename in test_filenames if "cpe" in filename])
print("CPE images count in training set: " + str(COUNT_CPE))
# Out:
# NORMAL images count in training set: 40
# CPE images count in training set: 64

# %% [markdown]
# #### tf.data 인스턴스를 만들기

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

# %% [markdown]
# #### train data와 val data의 개수 확인

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print("Training images count: " + str(TRAIN_IMG_COUNT))

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print("Validating images count: " + str(VAL_IMG_COUNT))
# Out:
# Training images count: 782
# Validating images count: 126

# %% [markdown]
# #### 라벨 이름들 확인

# %%
CLASS_NAMES = np.array([str(tf.strings.split(item, os.path.sep)[-1].numpy())[2:-1]
                        for item in tf.io.gfile.glob(str(ROOT_PATH + "/train/*"))])
print(CLASS_NAMES)
# Out:
# ['normal' 'cpe']

# %% [markdown]
# #### 라벨링 함수를 만들어 보기

# %%
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == "cpe"

# %% [markdown]
# #### decode_img 함수와 process_path 함수를 만들기

# %%
def decode_img(img):
  # 이미지를 uint8 tensor로 바꾼다.
  img = tf.image.decode_jpeg(img, channels=1)
  # img를 범위 [0,1]의 float32 데이터 타입으로 바꾼다.
  img = tf.image.convert_image_dtype(img, tf.float32)
  # img의 이미지 사이즈를 IMAGE_SIZE에서 지정한 사이즈로 수정한다.
  return tf.image.resize(img, IMAGE_SIZE)

def process_path(file_path):
    label = get_label(file_path)
    if label == True:
        label = ([0, 1])
    else:
        label = ([1, 0])
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    return img, label

# %% [markdown]
# #### train과 val에 함수들 적용해주기

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function get_label at 0x7f7a5c16c950> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function get_label at 0x7f7a5c16c950> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert

# %%
train_ds
# Out:
# <ParallelMapDataset shapes: ((1024, 1360, 1), (2,)), types: (tf.float32, tf.int32)>

# %% [markdown]
# #### 전처리 함수 만들기 및 적용

# %%
# def augment_LR(image,label):
#     image = tf.image.random_flip_left_right(image)  # 랜덤하게 좌우를 반전합니다.
#     return image,label

def prepare_for_training(ds, shuffle_buffer_size=1000):
    
#     ds = ds.map(
#             augment_LR,       # augment 함수 적용
#             num_parallel_calls=2
#         )    

    ds = ds.shuffle(buffer_size=shuffle_buffer_size)

    ds = ds.repeat()

    ds = ds.batch(BATCH_SIZE)

    ds = ds.prefetch(buffer_size=AUTOTUNE)

    return ds

train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %% [markdown]
# #### Image shape를 변경 체크하기

# %%
for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy().shape)
# Out:
# Image shape:  (32, 1024, 1360, 1)
# Label:  (32, 2)

# %% [markdown]
# #### test 데이터 셋도 만들어 보기 & 데이터의 갯수 확인

# %%
test_list_ds = tf.data.Dataset.list_files(str(ROOT_PATH + '/test/*/*'))
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

print(TEST_IMAGE_COUNT)
# Out:
# 104

# %% [markdown]
# ## Step 3. 데이터 시각화
#
# #### 16개의 샘플 꺼내서 확인

# %%
image_batch, label_batch = next(iter(train_ds))

def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(16):
        ax = plt.subplot(4,4,n+1)
        plt.imshow(image_batch[n])
        if list(label_batch[n])[0].numpy() == 0:
            plt.title("CPE")
        else:
            plt.title("NORMAL")
        plt.axis("off")

show_batch(image_batch.numpy(), label_batch)

# %% [markdown]
# #### model building

# %%
# conv_layer = [    
#     # convolution and then pooling
#     Conv2D(20, (7, 7), input_shape=(1024,1360,1), name='first_conv_layer',padding='valid'),
#     Activation('relu'),
#     MaxPooling2D(pool_size=(10, 10), padding='valid'),

#     # convolution and then pooling
#     Conv2D(25, (5, 5), name='second_conv_layer', padding='valid'),
#     Activation('relu'),
#     MaxPooling2D(pool_size=(6, 6), padding='valid'),
    
#     # convolution and then pooling
#     Conv2D(30, (3, 3), name='third_conv_layer', padding='valid'),
#     Activation('relu'),
#     MaxPooling2D(pool_size=(6, 6), padding='valid')
# ]

# fc_layer = [
#     # flatten and connect with three fully connected layer
#     Flatten(),
#     Dense(100, name='fc_layer_100_1'),
#     Activation('sigmoid'),
#     Dense(100, name='fc_layer_100_2',kernel_constraint= MaxNorm(1.)),
#     Activation('sigmoid'),
#     Dense(100, name='fc_layer_100_3',kernel_regularizer=regularizers.l2(0.01)),
#     Activation('sigmoid'),
 
#     # conneted with smaller fully connected layer
#     # with the same number of neurons as the number of classes
#     Dense(2, name='fc_layer_2'),
#     Activation('softmax')
# ]

# model = Sequential(conv_layer + fc_layer)

# %%
# import cv2

# sample_image = cv2.imread(ROOT_PATH + "/train/cpe/6.png")

# %%
# sample_image.shape

# %%
# img = np.asarray(Image.open(ROOT_PATH + "/train/cpe/6.png"))
# print("img :", np.shape(img))

# %%
# r = 0.2989
# g = 0.5870
# b = 0.1140
# gray = img[:,:,0]*r + img[:,:,1]*g + img[:,:,2]*b
# print("gray :", np.shape(gray))

# %%
model = load_model(os.getenv('HOME') + '/cellpin/0816_influ_filter_model_1')

# %%
# model.summary()

# %% [markdown]
# ## Step 5. 데이터 imbalance 처리
#
# #### 이 weight들은 'Normal'과 'Cpe' 전체 데이터 건수에 반비례하도록 설정

# %%
# weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
# weight_for_1 = (1 / COUNT_CPE)*(TRAIN_IMG_COUNT)/2.0

# class_weight = {0: weight_for_0, 1: weight_for_1}

# print('Weight for class 0: {:.2f}'.format(weight_for_0))
# print('Weight for class 1: {:.2f}'.format(weight_for_1))

# %% [markdown]
# ## Step 6. 모델 훈련
#
# #### GPU사용하여 model complie

# %%
with tf.device('/GPU:0'):
    model

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )
    
    # early_stopping = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', patience = 2, restore_best_weights = True)
    check_point = tf.keras.callbacks.ModelCheckpoint('best_model_basic.h5')

# %% [markdown]
# #### 모델 fitting

# %%
check_point = tf.keras.callbacks.ModelCheckpoint('best_model_basic.h5')

# %%
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
#         class_weight=class_weight,
        callbacks=[check_point]
    )
# Out:
# Epoch 1/150
# 24/24 [==============================] - 23s 519ms/step - loss: 0.8031 - accuracy: 0.5671 - precision: 0.5671 - recall: 0.5671 - val_loss: 0.6723 - val_accuracy: 0.6146 - val_precision: 0.6146 - val_recall: 0.6146
# Epoch 2/150
# 24/24 [==============================] - 11s 475ms/step - loss: 0.7111 - accuracy: 0.5315 - precision: 0.5315 - recall: 0.5315 - val_loss: 0.6765 - val_accuracy: 0.5833 - val_precision: 0.5833 - val_recall: 0.5833
# Epoch 3/150
# 24/24 [==============================] - 11s 461ms/step - loss: 0.6751 - accuracy: 0.5874 - precision: 0.5874 - recall: 0.5874 - val_loss: 0.7020 - val_accuracy: 0.4688 - val_precision: 0.4688 - val_recall: 0.4688
# Epoch 4/150
# 24/24 [==============================] - 11s 458ms/step - loss: 0.6634 - accuracy: 0.6292 - precision: 0.6292 - recall: 0.6292 - val_loss: 0.6476 - val_accuracy: 0.6042 - val_precision: 0.6042 - val_recall: 0.6042
# Epoch 5/150
# 24/24 [==============================] - 11s 480ms/step - loss: 0.6356 - accuracy: 0.6534 - precision: 0.6534 - recall: 0.6534 - val_loss: 0.6799 - val_accuracy: 0.5521 - val_precision: 0.5521 - val_recall: 0.5521
# Epoch 6/150
# 24/24 [==============================] - 11s 449ms/step - loss: 0.6448 - accuracy: 0.5964 - precision: 0.5964 - recall: 0.5964 - val_loss: 0.5827 - val_accuracy: 0.6979 - val_precision: 0.6979 - val_recall: 0.6979
# Epoch 7/150
# 24/24 [==============================] - 11s 458ms/step - loss: 0.5922 - accuracy: 0.6771 - precision: 0.6771 - recall: 0.6771 - val_loss: 0.5821 - val_accuracy: 0.7083 - val_precision: 0.7083 - val_recall: 0.7083
# Epoch 8/150
# 24/24 [==============================] - 11s 484ms/step - loss: 0.5496 - accuracy: 0.7377 - precision: 0.7377 - recall: 0.7377 - val_loss: 0.6245 - val_accuracy: 0.6458 - val_precision: 0.6458 - val_recall: 0.6458
# Epoch 9/150
# 24/24 [==============================] - 11s 483ms/step - loss: 0.5115 - accuracy: 0.7347 - precision: 0.7347 - recall: 0.7347 - val_loss: 0.6067 - val_accuracy: 0.6667 - val_precision: 0.6667 - val_recall: 0.6667
# Epoch 10/150
# 24/24 [==============================] - 11s 474ms/step - loss: 0.5484 - accuracy: 0.6973 - precision: 0.6973 - recall: 0.6973 - val_loss: 0.4691 - val_accuracy: 0.7708 - val_precision: 0.7708 - val_recall: 0.7708
# Epoch 11/150
# 24/24 [==============================] - 11s 474ms/step - loss: 0.4632 - accuracy: 0.7925 - precision: 0.7925 - recall: 0.7925 - val_loss: 0.4822 - val_accuracy: 0.7812 - val_precision: 0.7812 - val_recall: 0.7812
# Epoch 12/150
# 24/24 [==============================] - 11s 479ms/step - loss: 0.4454 - accuracy: 0.7987 - precision: 0.7987 - recall: 0.7987 - val_loss: 0.5431 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500
# Epoch 13/150
# 24/24 [==============================] - 11s 485ms/step - loss: 0.3868 - accuracy: 0.8308 - precision: 0.8308 - recall: 0.8308 - val_loss: 0.7193 - val_accuracy: 0.6250 - val_precision: 0.6250 - val_recall: 0.6250
# Epoch 14/150
# 24/24 [==============================] - 11s 482ms/step - loss: 0.4015 - accuracy: 0.8440 - precision: 0.8440 - recall: 0.8440 - val_loss: 0.3480 - val_accuracy: 0.8646 - val_precision: 0.8646 - val_recall: 0.8646
# Epoch 15/150
# 24/24 [==============================] - 12s 497ms/step - loss: 0.3520 - accuracy: 0.8495 - precision: 0.8495 - recall: 0.8495 - val_loss: 0.3750 - val_accuracy: 0.8229 - val_precision: 0.8229 - val_recall: 0.8229
# Epoch 16/150
# 24/24 [==============================] - 11s 483ms/step - loss: 0.2414 - accuracy: 0.9151 - precision: 0.9151 - recall: 0.9151 - val_loss: 0.5718 - val_accuracy: 0.7708 - val_precision: 0.7708 - val_recall: 0.7708
# Epoch 17/150
# 24/24 [==============================] - 11s 470ms/step - loss: 0.3677 - accuracy: 0.8503 - precision: 0.8503 - recall: 0.8503 - val_loss: 0.3204 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750
# Epoch 18/150
# 24/24 [==============================] - 11s 474ms/step - loss: 0.2390 - accuracy: 0.9247 - precision: 0.9247 - recall: 0.9247 - val_loss: 0.3243 - val_accuracy: 0.8854 - val_precision: 0.8854 - val_recall: 0.8854
# Epoch 19/150
# 24/24 [==============================] - 11s 475ms/step - loss: 0.2564 - accuracy: 0.9157 - precision: 0.9157 - recall: 0.9157 - val_loss: 0.2130 - val_accuracy: 0.9167 - val_precision: 0.9167 - val_recall: 0.9167
# Epoch 20/150
# 24/24 [==============================] - 11s 465ms/step - loss: 0.2295 - accuracy: 0.9024 - precision: 0.9024 - recall: 0.9024 - val_loss: 0.2777 - val_accuracy: 0.9062 - val_precision: 0.9062 - val_recall: 0.9062
# Epoch 21/150
# 24/24 [==============================] - 11s 452ms/step - loss: 0.2775 - accuracy: 0.8798 - precision: 0.8798 - recall: 0.8798 - val_loss: 0.3242 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750
# Epoch 22/150
# 24/24 [==============================] - 11s 473ms/step - loss: 0.2558 - accuracy: 0.9041 - precision: 0.9041 - recall: 0.9041 - val_loss: 0.3170 - val_accuracy: 0.8646 - val_precision: 0.8646 - val_recall: 0.8646
# Epoch 23/150
# 24/24 [==============================] - 11s 471ms/step - loss: 0.2215 - accuracy: 0.9130 - precision: 0.9130 - recall: 0.9130 - val_loss: 0.1883 - val_accuracy: 0.9688 - val_precision: 0.9688 - val_recall: 0.9688
# Epoch 24/150
# 24/24 [==============================] - 11s 482ms/step - loss: 0.2136 - accuracy: 0.9253 - precision: 0.9253 - recall: 0.9253 - val_loss: 0.2476 - val_accuracy: 0.9167 - val_precision: 0.9167 - val_recall: 0.9167
# Epoch 25/150
# 24/24 [==============================] - 12s 493ms/step - loss: 0.1808 - accuracy: 0.9369 - precision: 0.9369 - recall: 0.9369 - val_loss: 0.2262 - val_accuracy: 0.8958 - val_precision: 0.8958 - val_recall: 0.8958
# Epoch 26/150
# 24/24 [==============================] - 11s 474ms/step - loss: 0.1629 - accuracy: 0.9483 - precision: 0.9483 - recall: 0.9483 - val_loss: 0.2373 - val_accuracy: 0.8958 - val_precision: 0.8958 - val_recall: 0.8958
# Epoch 27/150
# 24/24 [==============================] - 11s 460ms/step - loss: 0.1678 - accuracy: 0.9429 - precision: 0.9429 - recall: 0.9429 - val_loss: 0.2640 - val_accuracy: 0.8646 - val_precision: 0.8646 - val_recall: 0.8646
# Epoch 28/150
# 24/24 [==============================] - 11s 456ms/step - loss: 0.1933 - accuracy: 0.9261 - precision: 0.9261 - recall: 0.9261 - val_loss: 0.1869 - val_accuracy: 0.9062 - val_precision: 0.9062 - val_recall: 0.9062
# Epoch 29/150
# 24/24 [==============================] - 11s 463ms/step - loss: 0.1651 - accuracy: 0.9373 - precision: 0.9373 - recall: 0.9373 - val_loss: 0.1680 - val_accuracy: 0.9479 - val_precision: 0.9479 - val_recall: 0.9479
# Epoch 30/150
# 24/24 [==============================] - 11s 476ms/step - loss: 0.1499 - accuracy: 0.9477 - precision: 0.9477 - recall: 0.9477 - val_loss: 0.2013 - val_accuracy: 0.9271 - val_precision: 0.9271 - val_recall: 0.9271
# Epoch 31/150
# 24/24 [==============================] - 11s 475ms/step - loss: 0.1327 - accuracy: 0.9600 - precision: 0.9600 - recall: 0.9600 - val_loss: 0.2838 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750
# Epoch 32/150
# 24/24 [==============================] - 11s 475ms/step - loss: 0.1686 - accuracy: 0.9311 - precision: 0.9311 - recall: 0.9311 - val_loss: 0.3592 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750
# Epoch 33/150
# 24/24 [==============================] - 11s 458ms/step - loss: 0.1621 - accuracy: 0.9349 - precision: 0.9349 - recall: 0.9349 - val_loss: 0.4358 - val_accuracy: 0.8229 - val_precision: 0.8229 - val_recall: 0.8229
# Epoch 34/150
# 24/24 [==============================] - 11s 477ms/step - loss: 0.1356 - accuracy: 0.9588 - precision: 0.9588 - recall: 0.9588 - val_loss: 0.2101 - val_accuracy: 0.9062 - val_precision: 0.9062 - val_recall: 0.9062
# Epoch
- val_accuracy: 0.9583 - val_precision: 0.9583 - val_recall: 0.9583
# Epoch 75/150
# 24/24 [==============================] - 11s 456ms/step - loss: 0.0287 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1626 - val_accuracy: 0.9479 - val_precision: 0.9479 - val_recall: 0.9479
# Epoch 76/150
# 24/24 [==============================] - 11s 471ms/step - loss: 0.0278 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1257 - val_accuracy: 0.9688 - val_precision: 0.9688 - val_recall: 0.9688
# Epoch 77/150
# 24/24 [==============================] - 11s 471ms/step - loss: 0.0270 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1479 - val_accuracy: 0.9583 - val_precision: 0.9583 - val_recall: 0.9583
# Epoch 78/150
# 24/24 [==============================] - 11s 459ms/step - loss: 0.0293 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.2540 - val_accuracy: 0.8958 - val_precision: 0.8958 - val_recall: 0.8958
# Epoch 79/150
# 24/24 [==============================] - 11s 475ms/step - loss: 0.0316 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1744 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375
# Epoch 80/150
# 24/24 [==============================] - 11s 463ms/step - loss: 0.0265 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1381 - val_accuracy: 0.9583 - val_precision: 0.9583 - val_recall: 0.9583
# Epoch 81/150
# 24/24 [==============================] - 11s 477ms/step - loss: 0.0251 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1631 - val_accuracy: 0.9479 - val_precision: 0.9479 - val_recall: 0.9479
# Epoch 82/150
# 24/24 [==============================] - 11s 479ms/step - loss: 0.0238 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1849 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375
# Epoch 83/150
# 24/24 [==============================] - 11s 472ms/step - loss: 0.0238 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1542 - val_accuracy: 0.9271 - val_precision: 0.9271 - val_recall: 0.9271
# Epoch 84/150
# 24/24 [==============================] - 11s 483ms/step - loss: 0.0286 - accuracy: 0.9998 - precision: 0.9998 - recall: 0.9998 - val_loss: 0.1389 - val_accuracy: 0.9583 - val_precision: 0.9583 - val_recall: 0.9583
# Epoch 85/150
# 24/24 [==============================] - 11s 462ms/step - loss: 0.0282 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1948 - val_accuracy: 0.9479 - val_precision: 0.9479 - val_recall: 0.9479
# Epoch 86/150
# 24/24 [==============================] - 11s 475ms/step - loss: 0.0287 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1409 - val_accuracy: 0.9688 - val_precision: 0.9688 - val_recall: 0.9688
# Epoch 87/150
# 24/24 [==============================] - 11s 481ms/step - loss: 0.0243 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1766 - val_accuracy: 0.9271 - val_precision: 0.9271 - val_recall: 0.9271
# Epoch 88/150
# 24/24 [==============================] - 11s 479ms/step - loss: 0.0209 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1352 - val_accuracy: 0.9688 - val_precision: 0.9688 - val_recall: 0.9688
# Epoch 89/150
# 24/24 [==============================] - 11s 486ms/step - loss: 0.0211 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1516 - val_accuracy: 0.9583 - val_precision: 0.9583 - val_recall: 0.9583
# Epoch 90/150
# 24/24 [==============================] - 11s 455ms/step - loss: 0.0212 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1548 - val_accuracy: 0.9479 - val_precision: 0.9479 - val_recall: 0.9479
# Epoch 91/150
# 24/24 [==============================] - 11s 474ms/step - loss: 0.0199 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1748 - val_accuracy: 0.9271 - val_precision: 0.9271 - val_recall: 0.9271
# Epoch 92/150
# 24/24 [==============================] - 11s 475ms/step - loss: 0.0199 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1324 - val_accuracy: 0.9479 - val_precision: 0.9479 - val_recall: 0.9479
# Epoch 93/150
# 24/24 [==============================] - 11s 458ms/step - loss: 0.0188 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1735 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375
# Epoch 94/150
# 24/24 [==============================] - 11s 479ms/step - loss: 0.0195 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1910 - val_accuracy: 0.9062 - val_precision: 0.9062 - val_recall: 0.9062
# Epoch 95/150
# 24/24 [==============================] - 11s 479ms/step - loss: 0.0208 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1089 - val_accuracy: 0.9792 - val_precision: 0.9792 - val_recall: 0.9792
# Epoch 96/150
# 24/24 [==============================] - 11s 477ms/step - loss: 0.0188 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1332 - val_accuracy: 0.9479 - val_precision: 0.9479 - val_recall: 0.9479
# Epoch 97/150
# 24/24 [==============================] - 11s 479ms/step - loss: 0.0177 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1526 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375
# Epoch 98/150
# 24/24 [==============================] - 11s 477ms/step - loss: 0.0177 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1117 - val_accuracy: 0.9479 - val_precision: 0.9479 - val_recall: 0.9479
# Epoch 99/150
# 24/24 [==============================] - 11s 479ms/step - loss: 0.0169 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1275 - val_accuracy: 0.9479 - val_precision: 0.9479 - val_recall: 0.9479
# Epoch 100/150
# 24/24 [==============================] - 11s 478ms/step - loss: 0.0178 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1271 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375
# Epoch 101/150
# 24/24 [==============================] - 11s 478ms/step - loss: 0.0166 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1360 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375
# Epoch 102/150
# 24/24 [==============================] - 11s 482ms/step - loss: 0.0168 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1378 - val_accuracy: 0.9583 - val_precision: 0.9583 - val_recall: 0.9583
# Epoch 103/150
# 24/24 [==============================] - 11s 478ms/step - loss: 0.0158 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1702 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375
# Epoch 104/150
# 24/24 [==============================] - 11s 461ms/step - loss: 0.0151 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1536 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375
# Epoch 105/150
# 24/24 [==============================] - 11s 479ms/step - loss: 0.0157 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1128 - val_accuracy: 0.9479 - val_precision: 0.9479 - val_recall: 0.9479
# Epoch 106/150
# 24/24 [==============================] - 11s 481ms/step - loss: 0.0156 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1780 - val_accuracy: 0.9271 - val_precision: 0.9271 - val_recall: 0.9271
# Epoch 107/150
# 24/24 [==============================] - 11s 476ms/step - loss: 0.0153 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.2204 - val_accuracy: 0.8958 - val_precision: 0.8958 - val_recall: 0.8958
# Epoch 108/150
# 24/24 [==============================] - 11s 455ms/step - loss: 0.0163 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1725 - val_accuracy: 0.9062 - val_precision: 0.9062 - val_recall: 0.9062
# Epoch 109/150
# 24/24 [==============================] - 11s 460ms/step - loss: 0.0146 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1292 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375
# Epoch 110/150
# 24/24 [==============================] - 11s 478ms/step - loss: 0.0145 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1393 - val_accuracy: 0.9479 - val_precision: 0.9479 - val_recall: 0.9479
# Epoch 111/150
# 24/24 [==============================] - 11s 480ms/step - loss: 0.0143 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1547 - val_accuracy: 0.9271 - val_precision: 0.9271 - val_recall: 0.9271
# Epoch 112/150
# 24/24 [==============================] - 11s 480ms/step - loss: 0.0139 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1526 - val_accuracy: 0.9479 - val_precision: 0.9479 - val_recall: 0.9479
# Epoch 113/150
# 24/24 [==============================] - 11s 482ms/step - loss: 0.0132 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0680 - val_accuracy: 0.9792 - val_precision: 0.9792 - val_recall: 0.9792
# Epoch 114/150
# 24/24 [==============================] - 11s 474ms/step - loss: 0.0149 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1649 - val_accuracy: 0.9479 - val_precision: 0.9479 - val_recall: 0.9479
# Epoch 115/150
# 24/24 [==============================] - 11s 457ms/step - loss: 0.0182 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1765 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375
# Epoch 116/150
# 24/24 [==============================] - 11s 478ms/step - loss: 0.0131 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1551 - val_accuracy: 0.9271 - val_precision: 0.9271 - val_recall: 0.9271
# Epoch 117/150
# 24/24 [==============================] - 11s 479ms/step - loss: 0.0123 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1651 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375
# Epoch 118/150
# 24/24 [==============================] - 11s 474ms/step - loss: 0.0124 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1512 - val_accuracy: 0.9271 - val_precision: 0.9271 - val_recall: 0.9271
# Epoch 119/150
# 24/24 [==============================] - 11s 475ms/step - loss: 0.0126 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1822 - val_accuracy: 0.9167 - val_precision: 0.9167 - val_recall: 0.9167
# Epoch 120/150
# 24/24 [==============================] - 11s 481ms/step - loss: 0.0130 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1431 - val_accuracy: 0.9271 - val_precision: 0.9271 - val_recall: 0.9271
# Epoch 121/150
# 24/24 [==============================] - 11s 480ms/step - loss: 0.0121 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1538 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375
# Epoch 122/150
# 24/24 [==============================] - 11s 462ms/step - loss: 0.0120 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1109 - val_accuracy: 0.9583 - val_precision: 0.9583 - val_recall: 0.9583
# Epoch 123/150
# 24/24 [==============================] - 11s 476ms/step - loss: 0.0112 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1638 - val_accuracy: 0.9271 - val_precision: 0.9271 - val_recall: 0.9271
# Epoch 124/150
# 24/24 [==============================] - 11s 478ms/step - loss: 0.0111 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1673 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375
# Epoch 125/150
# 24/24 [==============================] - 11s 479ms/step - loss: 0.0128 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1760 - val_accuracy: 0.9167 - val_precision: 0.9167 - val_recall: 0.9167
# Epoch 126/150
# 24/24 [==============================] - 11s 478ms/step - loss: 0.0112 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1282 - val_accuracy: 0.9479 - val_precision: 0.9479 - val_recall: 0.9479
# Epoch 127/150
# 24/24 [==============================] - 11s 482ms/step - loss: 0.0110 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1585 - val_accuracy: 0.9271 - val_precision: 0.9271 - val_recall: 0.9271
# Epoch 128/150
# 24/24 [==============================] - 11s 481ms/step - loss: 0.0111 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1590 - val_accuracy: 0.9167 - val_precision: 0.9167 - val_recall: 0.9167
# Epoch 129/150
# 24/24 [==============================] - 11s 480ms/step - loss: 0.0100 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1685 - val_accuracy: 0.9271 - val_precision: 0.9271 - val_recall: 0.9271
# Epoch 130/150
# 24/24 [==============================] - 11s 487ms/step - loss: 0.0106 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1758 - val_accuracy: 0.9271 - val_precision: 0.9271 - val_recall: 0.9271
# Epoch 131/150
# 24/24 [==============================] - 12s 490ms/step - loss: 0.0106 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1836 - val_accuracy: 0.9167 - val_precision: 0.9167 - val_recall: 0.9167
# Epoch 132/150
# 24/24 [==============================] - 11s 468ms/step - loss: 0.0103 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1768 - val_accuracy: 0.9271 - val_precision: 0.9271 - val_recall: 0.9271
# Epoch 133/150
# 24/24 [==============================] - 11s 470ms/step - loss: 0.0098 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1863 - val_accuracy: 0.9271 - val_precision: 0.9271 - val_recall: 0.9271
# Epoch 134/150
# 24/24 [==============================] - 11s 471ms/step - loss: 0.0108 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.2051 - val_accuracy: 0.9167 - val_precision: 0.9167 - val_recall: 0.9167
# Epoch 135/150
# 24/24 [==============================] - 11s 467ms/step - loss: 0.0093 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1692 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375
# Epoch 136/150
# 24/24 [==============================] - 11s 476ms/step - loss: 0.0099 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1744 - val_accuracy: 0.9167 - val_precision: 0.9167 - val_recall: 0.9167
# Epoch 137/150
# 24/24 [==============================] - 11s 482ms/step - loss: 0.0091 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1117 - val_accuracy: 0.9271 - val_precision: 0.9271 - val_recall: 0.9271
# Epoch 138/150
# 24/24 [==============================] - 11s 479ms/step - loss: 0.0093 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1030 - val_accuracy: 0.9583 - val_precision: 0.9583 - val_recall: 0.9583
# Epoch 139/150
# 24/24 [==============================] - 11s 458ms/step - loss: 0.0100 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1726 - val_accuracy: 0.9271 - val_precision: 0.9271 - val_recall: 0.9271
# Epoch 140/150
# 24/24 [==============================] - 11s 479ms/step - loss: 0.0090 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1399 - val_accuracy: 0.9271 - val_precision: 0.9271 - val_recall: 0.9271
# Epoch 141/150
# 24/24 [==============================] - 11s 474ms/step - loss: 0.0096 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.2198 - val_accuracy: 0.9062 - val_precision: 0.9062 - val_recall: 0.9062
# Epoch 142/150
# 24/24 [==============================] - 11s 476ms/step - loss: 0.0092 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1134 - val_accuracy: 0.9479 - val_precision: 0.9479 - val_recall: 0.9479
# Epoch 143/150
# 24/24 [==============================] - 11s 480ms/step - loss: 0.0099 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1912 - val_accuracy: 0.9271 - val_precision: 0.9271 - val_recall: 0.9271
# Epoch 144/150
# 24/24 [==============================] - 11s 480ms/step - loss: 0.0092 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1519 - val_accuracy: 0.9271 - val_precision: 0.9271 - val_recall: 0.9271
# Epoch 145/150
# 24/24 [==============================] - 11s 481ms/step - loss: 0.0086 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1339 - val_accuracy: 0.9479 - val_precision: 0.9479 - val_recall: 0.9479
# Epoch 146/150
# 24/24 [==============================] - 11s 481ms/step - loss: 0.0085 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1562 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375
# Epoch 147/150
# 24/24 [==============================] - 11s 464ms/step - loss: 0.0083 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1469 - val_accuracy: 0.9271 - val_precision: 0.9271 - val_recall: 0.9271
# Epoch 148/150
# 24/24 [==============================] - 11s 485ms/step - loss: 0.0081 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1520 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375
# Epoch 149/150
# 24/24 [==============================] - 11s 477ms/step - loss: 0.0084 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.1555 - val_accuracy: 0.9271 - val_precision: 0.9271 - val_recall: 0.9271
# Epoch 150/150
# 24/24 [==============================] - 11s 481ms/step - loss: 0.0081 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0898 - val_accuracy: 0.9688 - val_precision: 0.9688 - val_recall: 0.9688

# %% [markdown]
# ## Step 7. 결과 확인 및 시각화

# %%
fig, ax = plt.subplots(2, 2, figsize=(10, 10))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ## Step 8. 최종 Test dataset 검정하기

# %%
model = tf.keras.models.load_model("best_model_basic.h5")
loss, acc, prec, rec = model.evaluate(test_ds)
# Out:
# 4/4 [==============================] - 1s 93ms/step - loss: 0.0948 - accuracy: 0.9712 - precision: 0.9712 - recall: 0.9712

# %% [markdown]
# ## Discussion
