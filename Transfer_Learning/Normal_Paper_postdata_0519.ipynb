# %% [markdown]
# # 1006개의 데이터로 Transfer_Learning 하기
#
# - 논문의 모델에 1006개의 데이터를 넣고 학습을 시켜보자
#
# ## Step 1. 실험환경 set-up
#
# #### 라이브러리 실행

# %%
from tensorflow.keras             import utils, regularizers
from tensorflow.keras.models      import Sequential, load_model
from tensorflow.keras.layers      import Conv2D, MaxPooling2D, AveragePooling2D, Dense, Dropout, Activation, Flatten
from tensorflow.keras.optimizers  import Adam
from tensorflow.keras.constraints import MaxNorm
from sklearn.model_selection      import train_test_split  # 데이터 전처리에 필요한 패키지

import os                       # I/O 관련된 작업에 필요한 패키지 
import numpy             as np  # 데이터 array 작업에 필요한 패키지
import tensorflow        as tf  # 딥러닝 관련된 작업에 필요한 패키지
import matplotlib.pyplot as plt # 데이터 시각화에 관련된 작업에 필요한 패키지

import re    # 정규표현식 관련된 작업에 필요한 패키지
import os    # I/O 관련된 작업에 필요한 패키지 
import pandas as pd     # 데이터 전처리 관련된 작업에 필요한 패키지
import numpy as np      # 데이터 array 작업에 필요한 패키지
import tensorflow as tf  # 딥러닝 관련된 작업에 필요한 패키지
import matplotlib.pyplot as plt    # 데이터 시각화에 관련된 작업에 필요한 패키지
from sklearn.model_selection import train_test_split  # 데이터 전처리에 필요한 패키지
from PIL import Image

# %% [markdown]
# #### 필요한 변수들 생성

# %%
# 데이터 로드할 때 빠르게 로드할 수 있도록하는 설정 변수
AUTOTUNE = tf.data.experimental.AUTOTUNE

# BATCH_SIZE 변수
BATCH_SIZE = 32

# 이미지 사이즈 변수
IMAGE_SIZE = [1024, 1360]

# EPOCH 크기 변수
EPOCHS = 150

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'),
#  PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %% [markdown]
# ## Step 2. 데이터 준비하기
#
# 먼저 아래의 링크에서 데이터를 다운 받을 것
#
# https://drive.google.com/drive/folders/1Pi5qyX080zY2IdGT1TvvLraBO9DHBxJl?usp=sharing
#
# 받은 후 터미널 창에 아래의 명령어들을 차례로 입력
#
# ```
# $ cd ~/Downloads && cp CellPin ~/aiffel
# ```
#
# #### 데이터의 개수 확인

# %%
# 데이터 ROOT 경로 변수
ROOT_PATH = os.path.join(os.getenv('HOME'), 'cellpin/CellPin')
print(ROOT_PATH)

train_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/train/*/*'))
test_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/test/*/*'))
val_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/val/*/*'))

print(len(train_filenames))
print(len(test_filenames))
print(len(val_filenames))
# Out:
# /home/mochafreddo/cellpin/CellPin
# 782
# 104
# 126

# %% [markdown]
# #### train과 validation을 80:20으로 분할

# %%
# filenames = tf.io.gfile.glob(str(ROOT_PATH + '/train/*/*'))
# filenames.extend(tf.io.gfile.glob(str(ROOT_PATH + '/val/*/*')))

# train_filenames, val_filenames = train_test_split(filenames, test_size=0.2)

# print(len(train_filenames))
# print(len(val_filenames))

# %% [markdown]
# #### train 데이터 안에 정상 이미지 수와 CPE 이미지 수

# %%
COUNT_NORMAL = len([filename for filename in train_filenames if "normal" in filename])
print("NORMAL images count in training set: " + str(COUNT_NORMAL))

COUNT_CPE = len([filename for filename in train_filenames if "cpe" in filename])
print("CPE images count in training set: " + str(COUNT_CPE))
# Out:
# NORMAL images count in training set: 355
# CPE images count in training set: 427

# %% [markdown]
# #### val 데이터 안에 정상 이미지 수와 CPE 이미지 수

# %%
COUNT_NORMAL = len([filename for filename in val_filenames if "normal" in filename])
print("NORMAL images count in training set: " + str(COUNT_NORMAL))

COUNT_CPE = len([filename for filename in val_filenames if "cpe" in filename])
print("CPE images count in training set: " + str(COUNT_CPE))
# Out:
# NORMAL images count in training set: 50
# CPE images count in training set: 76

# %% [markdown]
# #### test 데이터 안에 정상 이미지 수와 CPE 이미지 수

# %%
COUNT_NORMAL = len([filename for filename in test_filenames if "normal" in filename])
print("NORMAL images count in training set: " + str(COUNT_NORMAL))

COUNT_CPE = len([filename for filename in test_filenames if "cpe" in filename])
print("CPE images count in training set: " + str(COUNT_CPE))
# Out:
# NORMAL images count in training set: 40
# CPE images count in training set: 64

# %% [markdown]
# #### tf.data 인스턴스를 만들기

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

# %% [markdown]
# #### train data와 val data의 개수 확인

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print("Training images count: " + str(TRAIN_IMG_COUNT))

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print("Validating images count: " + str(VAL_IMG_COUNT))
# Out:
# Training images count: 782
# Validating images count: 126

# %% [markdown]
# #### 라벨 이름들 확인

# %%
CLASS_NAMES = np.array([str(tf.strings.split(item, os.path.sep)[-1].numpy())[2:-1]
                        for item in tf.io.gfile.glob(str(ROOT_PATH + "/train/*"))])
print(CLASS_NAMES)
# Out:
# ['normal' 'cpe']

# %% [markdown]
# #### 라벨링 함수를 만들어 보기

# %%
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == "cpe"

# %% [markdown]
# #### decode_img 함수와 process_path 함수를 만들기

# %%
def decode_img(img):
  # 이미지를 uint8 tensor로 바꾼다.
  img = tf.image.decode_jpeg(img, channels=1)
  # img를 범위 [0,1]의 float32 데이터 타입으로 바꾼다.
  img = tf.image.convert_image_dtype(img, tf.float32)
  # img의 이미지 사이즈를 IMAGE_SIZE에서 지정한 사이즈로 수정한다.
  return tf.image.resize(img, IMAGE_SIZE)

def process_path(file_path):
    label = get_label(file_path)
    if label == True:
        label = ([0, 1])
    else:
        label = ([1, 0])
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    return img, label

# %% [markdown]
# #### train과 val에 함수들 적용해주기

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function get_label at 0x7f841c25d950> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function get_label at 0x7f841c25d950> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert

# %%
train_ds
# Out:
# <ParallelMapDataset shapes: ((1024, 1360, 1), (2,)), types: (tf.float32, tf.int32)>

# %% [markdown]
# #### 전처리 함수 만들기 및 적용

# %%
# def augment_LR(image,label):
#     image = tf.image.random_flip_left_right(image)  # 랜덤하게 좌우를 반전합니다.
#     return image,label

def prepare_for_training(ds, shuffle_buffer_size=1000):
    
#     ds = ds.map(
#             augment_LR,       # augment 함수 적용
#             num_parallel_calls=2
#         )    

    ds = ds.shuffle(buffer_size=shuffle_buffer_size)

    ds = ds.repeat()

    ds = ds.batch(BATCH_SIZE)

    ds = ds.prefetch(buffer_size=AUTOTUNE)

    return ds

train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %% [markdown]
# #### Image shape를 변경 체크하기

# %%
for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy().shape)
# Out:
# Image shape:  (32, 1024, 1360, 1)
# Label:  (32, 2)

# %% [markdown]
# #### test 데이터 셋도 만들어 보기 & 데이터의 갯수 확인

# %%
test_list_ds = tf.data.Dataset.list_files(str(ROOT_PATH + '/test/*/*'))
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

print(TEST_IMAGE_COUNT)
# Out:
# 104

# %% [markdown]
# ## Step 3. 데이터 시각화
#
# #### 16개의 샘플 꺼내서 확인

# %%
image_batch, label_batch = next(iter(train_ds))

def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(16):
        ax = plt.subplot(4,4,n+1)
        plt.imshow(image_batch[n])
        if list(label_batch[n])[0].numpy() == 0:
            plt.title("CPE")
        else:
            plt.title("NORMAL")
        plt.axis("off")

show_batch(image_batch.numpy(), label_batch)

# %% [markdown]
# #### model building

# %%
conv_layer = [    
    # convolution and then pooling
    Conv2D(20, (7, 7), input_shape=(1024,1360,1), name='first_conv_layer',padding='valid'),
    Activation('relu'),
    MaxPooling2D(pool_size=(10, 10), padding='valid'),

    # convolution and then pooling
    Conv2D(25, (5, 5), name='second_conv_layer', padding='valid'),
    Activation('relu'),
    MaxPooling2D(pool_size=(6, 6), padding='valid'),
    
    # convolution and then pooling
    Conv2D(30, (3, 3), name='third_conv_layer', padding='valid'),
    Activation('relu'),
    MaxPooling2D(pool_size=(6, 6), padding='valid')
]

fc_layer = [
    # flatten and connect with three fully connected layer
    Flatten(),
    Dense(100, name='fc_layer_100_1'),
    Activation('sigmoid'),
    Dense(100, name='fc_layer_100_2',kernel_constraint= MaxNorm(1.)),
    Activation('sigmoid'),
    Dense(100, name='fc_layer_100_3',kernel_regularizer=regularizers.l2(0.01)),
    Activation('sigmoid'),
 
    # conneted with smaller fully connected layer
    # with the same number of neurons as the number of classes
    Dense(2, name='fc_layer_2'),
    Activation('softmax')
]

model = Sequential(conv_layer + fc_layer)

# %%
# import cv2

# sample_image = cv2.imread(ROOT_PATH + "/train/cpe/6.png")

# %%
# sample_image.shape

# %%
# img = np.asarray(Image.open(ROOT_PATH + "/train/cpe/6.png"))
# print("img :", np.shape(img))

# %%
# r = 0.2989
# g = 0.5870
# b = 0.1140
# gray = img[:,:,0]*r + img[:,:,1]*g + img[:,:,2]*b
# print("gray :", np.shape(gray))

# %%
# model = load_model(os.getenv('HOME') + '/cellpin/0816_influ_filter_model_1')

# %%
# model.summary()

# %% [markdown]
# ## Step 5. 데이터 imbalance 처리
#
# #### 이 weight들은 'Normal'과 'Cpe' 전체 데이터 건수에 반비례하도록 설정

# %%
# weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
# weight_for_1 = (1 / COUNT_CPE)*(TRAIN_IMG_COUNT)/2.0

# class_weight = {0: weight_for_0, 1: weight_for_1}

# print('Weight for class 0: {:.2f}'.format(weight_for_0))
# print('Weight for class 1: {:.2f}'.format(weight_for_1))

# %% [markdown]
# ## Step 6. 모델 훈련
#
# #### GPU사용하여 model complie

# %%
with tf.device('/GPU:0'):

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )
    
    # early_stopping = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', patience = 2, restore_best_weights = True)
    check_point = tf.keras.callbacks.ModelCheckpoint('best_model_basic.h5')

# %% [markdown]
# #### 모델 fitting

# %%
check_point = tf.keras.callbacks.ModelCheckpoint('best_model_basic.h5')

# %%
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
#         class_weight=class_weight,
        callbacks=[check_point]
    )
# Out:
# Epoch 1/150
# 24/24 [==============================] - 22s 490ms/step - loss: 1.6216 - accuracy: 0.5159 - precision: 0.5159 - recall: 0.5159 - val_loss: 1.3795 - val_accuracy: 0.4062 - val_precision: 0.4062 - val_recall: 0.4062
# Epoch 2/150
# 24/24 [==============================] - 11s 473ms/step - loss: 1.3147 - accuracy: 0.4935 - precision: 0.4935 - recall: 0.4935 - val_loss: 1.1433 - val_accuracy: 0.6354 - val_precision: 0.6354 - val_recall: 0.6354
# Epoch 3/150
# 24/24 [==============================] - 11s 470ms/step - loss: 1.1040 - accuracy: 0.5074 - precision: 0.5074 - recall: 0.5074 - val_loss: 0.9685 - val_accuracy: 0.6146 - val_precision: 0.6146 - val_recall: 0.6146
# Epoch 4/150
# 24/24 [==============================] - 11s 469ms/step - loss: 0.9591 - accuracy: 0.5453 - precision: 0.5453 - recall: 0.5453 - val_loss: 0.8793 - val_accuracy: 0.5833 - val_precision: 0.5833 - val_recall: 0.5833
# Epoch 5/150
# 24/24 [==============================] - 11s 474ms/step - loss: 0.8635 - accuracy: 0.5386 - precision: 0.5386 - recall: 0.5386 - val_loss: 0.8006 - val_accuracy: 0.6042 - val_precision: 0.6042 - val_recall: 0.6042
# Epoch 6/150
# 24/24 [==============================] - 11s 475ms/step - loss: 0.7924 - accuracy: 0.5884 - precision: 0.5884 - recall: 0.5884 - val_loss: 0.7642 - val_accuracy: 0.6146 - val_precision: 0.6146 - val_recall: 0.6146
# Epoch 7/150
# 24/24 [==============================] - 11s 473ms/step - loss: 0.7583 - accuracy: 0.5593 - precision: 0.5593 - recall: 0.5593 - val_loss: 0.7267 - val_accuracy: 0.6354 - val_precision: 0.6354 - val_recall: 0.6354
# Epoch 8/150
# 24/24 [==============================] - 11s 469ms/step - loss: 0.7302 - accuracy: 0.5610 - precision: 0.5610 - recall: 0.5610 - val_loss: 0.7073 - val_accuracy: 0.5938 - val_precision: 0.5938 - val_recall: 0.5938
# Epoch 9/150
# 24/24 [==============================] - 11s 475ms/step - loss: 0.7169 - accuracy: 0.5366 - precision: 0.5366 - recall: 0.5366 - val_loss: 0.7054 - val_accuracy: 0.5521 - val_precision: 0.5521 - val_recall: 0.5521
# Epoch 10/150
# 24/24 [==============================] - 11s 452ms/step - loss: 0.7086 - accuracy: 0.5387 - precision: 0.5387 - recall: 0.5387 - val_loss: 0.6901 - val_accuracy: 0.5833 - val_precision: 0.5833 - val_recall: 0.5833
# Epoch 11/150
# 24/24 [==============================] - 11s 476ms/step - loss: 0.7049 - accuracy: 0.5183 - precision: 0.5183 - recall: 0.5183 - val_loss: 0.6900 - val_accuracy: 0.5938 - val_precision: 0.5938 - val_recall: 0.5938
# Epoch 12/150
# 24/24 [==============================] - 11s 471ms/step - loss: 0.7030 - accuracy: 0.5331 - precision: 0.5331 - recall: 0.5331 - val_loss: 0.6873 - val_accuracy: 0.5833 - val_precision: 0.5833 - val_recall: 0.5833
# Epoch 13/150
# 24/24 [==============================] - 11s 471ms/step - loss: 0.6907 - accuracy: 0.5635 - precision: 0.5635 - recall: 0.5635 - val_loss: 0.6939 - val_accuracy: 0.5312 - val_precision: 0.5312 - val_recall: 0.5312
# Epoch 14/150
# 24/24 [==============================] - 11s 458ms/step - loss: 0.6931 - accuracy: 0.5379 - precision: 0.5379 - recall: 0.5379 - val_loss: 0.6914 - val_accuracy: 0.5417 - val_precision: 0.5417 - val_recall: 0.5417
# Epoch 15/150
# 24/24 [==============================] - 11s 454ms/step - loss: 0.6898 - accuracy: 0.5554 - precision: 0.5554 - recall: 0.5554 - val_loss: 0.6794 - val_accuracy: 0.5938 - val_precision: 0.5938 - val_recall: 0.5938
# Epoch 16/150
# 24/24 [==============================] - 11s 470ms/step - loss: 0.6908 - accuracy: 0.5434 - precision: 0.5434 - recall: 0.5434 - val_loss: 0.6698 - val_accuracy: 0.6250 - val_precision: 0.6250 - val_recall: 0.6250
# Epoch 17/150
# 24/24 [==============================] - 12s 476ms/step - loss: 0.7009 - accuracy: 0.5066 - precision: 0.5066 - recall: 0.5066 - val_loss: 0.6912 - val_accuracy: 0.5521 - val_precision: 0.5521 - val_recall: 0.5521
# Epoch 18/150
# 24/24 [==============================] - 11s 473ms/step - loss: 0.6902 - accuracy: 0.5465 - precision: 0.5465 - recall: 0.5465 - val_loss: 0.6816 - val_accuracy: 0.5833 - val_precision: 0.5833 - val_recall: 0.5833
# Epoch
- val_accuracy: 0.6250 - val_precision: 0.6250 - val_recall: 0.6250
# Epoch 117/150
# 24/24 [==============================] - 11s 455ms/step - loss: 0.6872 - accuracy: 0.5741 - precision: 0.5741 - recall: 0.5741 - val_loss: 0.6737 - val_accuracy: 0.6042 - val_precision: 0.6042 - val_recall: 0.6042
# Epoch 118/150
# 24/24 [==============================] - 11s 477ms/step - loss: 0.6903 - accuracy: 0.5452 - precision: 0.5452 - recall: 0.5452 - val_loss: 0.6769 - val_accuracy: 0.6042 - val_precision: 0.6042 - val_recall: 0.6042
# Epoch 119/150
# 24/24 [==============================] - 11s 459ms/step - loss: 0.6985 - accuracy: 0.5009 - precision: 0.5009 - recall: 0.5009 - val_loss: 0.6801 - val_accuracy: 0.6042 - val_precision: 0.6042 - val_recall: 0.6042
# Epoch 120/150
# 24/24 [==============================] - 11s 476ms/step - loss: 0.6899 - accuracy: 0.5439 - precision: 0.5439 - recall: 0.5439 - val_loss: 0.6805 - val_accuracy: 0.5938 - val_precision: 0.5938 - val_recall: 0.5938
# Epoch 121/150
# 24/24 [==============================] - 11s 479ms/step - loss: 0.6888 - accuracy: 0.5498 - precision: 0.5498 - recall: 0.5498 - val_loss: 0.6877 - val_accuracy: 0.5521 - val_precision: 0.5521 - val_recall: 0.5521
# Epoch 122/150
# 24/24 [==============================] - 11s 473ms/step - loss: 0.6876 - accuracy: 0.5545 - precision: 0.5545 - recall: 0.5545 - val_loss: 0.6800 - val_accuracy: 0.6042 - val_precision: 0.6042 - val_recall: 0.6042
# Epoch 123/150
# 24/24 [==============================] - 11s 475ms/step - loss: 0.6880 - accuracy: 0.5553 - precision: 0.5553 - recall: 0.5553 - val_loss: 0.6774 - val_accuracy: 0.6042 - val_precision: 0.6042 - val_recall: 0.6042
# Epoch 124/150
# 24/24 [==============================] - 11s 473ms/step - loss: 0.6932 - accuracy: 0.5256 - precision: 0.5256 - recall: 0.5256 - val_loss: 0.6855 - val_accuracy: 0.5729 - val_precision: 0.5729 - val_recall: 0.5729
# Epoch 125/150
# 24/24 [==============================] - 11s 478ms/step - loss: 0.6888 - accuracy: 0.5545 - precision: 0.5545 - recall: 0.5545 - val_loss: 0.6773 - val_accuracy: 0.6042 - val_precision: 0.6042 - val_recall: 0.6042
# Epoch 126/150
# 24/24 [==============================] - 11s 486ms/step - loss: 0.6892 - accuracy: 0.5478 - precision: 0.5478 - recall: 0.5478 - val_loss: 0.6822 - val_accuracy: 0.5833 - val_precision: 0.5833 - val_recall: 0.5833
# Epoch 127/150
# 24/24 [==============================] - 11s 479ms/step - loss: 0.6851 - accuracy: 0.5688 - precision: 0.5688 - recall: 0.5688 - val_loss: 0.6737 - val_accuracy: 0.6458 - val_precision: 0.6458 - val_recall: 0.6458
# Epoch 128/150
# 24/24 [==============================] - 11s 462ms/step - loss: 0.6875 - accuracy: 0.5572 - precision: 0.5572 - recall: 0.5572 - val_loss: 0.6700 - val_accuracy: 0.6562 - val_precision: 0.6562 - val_recall: 0.6562
# Epoch 129/150
# 24/24 [==============================] - 11s 457ms/step - loss: 0.6887 - accuracy: 0.5513 - precision: 0.5513 - recall: 0.5513 - val_loss: 0.6782 - val_accuracy: 0.6042 - val_precision: 0.6042 - val_recall: 0.6042
# Epoch 130/150
# 24/24 [==============================] - 11s 473ms/step - loss: 0.6922 - accuracy: 0.5366 - precision: 0.5366 - recall: 0.5366 - val_loss: 0.6756 - val_accuracy: 0.6146 - val_precision: 0.6146 - val_recall: 0.6146
# Epoch 131/150
# 24/24 [==============================] - 11s 453ms/step - loss: 0.6916 - accuracy: 0.5330 - precision: 0.5330 - recall: 0.5330 - val_loss: 0.6799 - val_accuracy: 0.5938 - val_precision: 0.5938 - val_recall: 0.5938
# Epoch 132/150
# 24/24 [==============================] - 11s 466ms/step - loss: 0.6923 - accuracy: 0.5289 - precision: 0.5289 - recall: 0.5289 - val_loss: 0.6702 - val_accuracy: 0.6250 - val_precision: 0.6250 - val_recall: 0.6250
# Epoch 133/150
# 24/24 [==============================] - 11s 473ms/step - loss: 0.6962 - accuracy: 0.5165 - precision: 0.5165 - recall: 0.5165 - val_loss: 0.6814 - val_accuracy: 0.6250 - val_precision: 0.6250 - val_recall: 0.6250
# Epoch 134/150
# 24/24 [==============================] - 11s 462ms/step - loss: 0.6859 - accuracy: 0.5766 - precision: 0.5766 - recall: 0.5766 - val_loss: 0.6684 - val_accuracy: 0.6250 - val_precision: 0.6250 - val_recall: 0.6250
# Epoch 135/150
# 24/24 [==============================] - 11s 453ms/step - loss: 0.6881 - accuracy: 0.5543 - precision: 0.5543 - recall: 0.5543 - val_loss: 0.6696 - val_accuracy: 0.6667 - val_precision: 0.6667 - val_recall: 0.6667
# Epoch 136/150
# 24/24 [==============================] - 11s 477ms/step - loss: 0.6900 - accuracy: 0.5406 - precision: 0.5406 - recall: 0.5406 - val_loss: 0.6829 - val_accuracy: 0.5729 - val_precision: 0.5729 - val_recall: 0.5729
# Epoch 137/150
# 24/24 [==============================] - 11s 479ms/step - loss: 0.6957 - accuracy: 0.5190 - precision: 0.5190 - recall: 0.5190 - val_loss: 0.6811 - val_accuracy: 0.5833 - val_precision: 0.5833 - val_recall: 0.5833
# Epoch 138/150
# 24/24 [==============================] - 11s 469ms/step - loss: 0.6924 - accuracy: 0.5312 - precision: 0.5312 - recall: 0.5312 - val_loss: 0.6753 - val_accuracy: 0.6458 - val_precision: 0.6458 - val_recall: 0.6458
# Epoch 139/150
# 24/24 [==============================] - 11s 474ms/step - loss: 0.6924 - accuracy: 0.5268 - precision: 0.5268 - recall: 0.5268 - val_loss: 0.6700 - val_accuracy: 0.6354 - val_precision: 0.6354 - val_recall: 0.6354
# Epoch 140/150
# 24/24 [==============================] - 11s 472ms/step - loss: 0.6897 - accuracy: 0.5482 - precision: 0.5482 - recall: 0.5482 - val_loss: 0.6821 - val_accuracy: 0.5833 - val_precision: 0.5833 - val_recall: 0.5833
# Epoch 141/150
# 24/24 [==============================] - 11s 472ms/step - loss: 0.6842 - accuracy: 0.5731 - precision: 0.5731 - recall: 0.5731 - val_loss: 0.6763 - val_accuracy: 0.6042 - val_precision: 0.6042 - val_recall: 0.6042
# Epoch 142/150
# 24/24 [==============================] - 11s 478ms/step - loss: 0.6885 - accuracy: 0.5496 - precision: 0.5496 - recall: 0.5496 - val_loss: 0.6874 - val_accuracy: 0.5938 - val_precision: 0.5938 - val_recall: 0.5938
# Epoch 143/150
# 24/24 [==============================] - 11s 475ms/step - loss: 0.6886 - accuracy: 0.5766 - precision: 0.5766 - recall: 0.5766 - val_loss: 0.6812 - val_accuracy: 0.6042 - val_precision: 0.6042 - val_recall: 0.6042
# Epoch 144/150
# 24/24 [==============================] - 11s 473ms/step - loss: 0.6885 - accuracy: 0.5557 - precision: 0.5557 - recall: 0.5557 - val_loss: 0.6788 - val_accuracy: 0.5938 - val_precision: 0.5938 - val_recall: 0.5938
# Epoch 145/150
# 24/24 [==============================] - 11s 475ms/step - loss: 0.6855 - accuracy: 0.5669 - precision: 0.5669 - recall: 0.5669 - val_loss: 0.6897 - val_accuracy: 0.5417 - val_precision: 0.5417 - val_recall: 0.5417
# Epoch 146/150
# 24/24 [==============================] - 11s 466ms/step - loss: 0.6916 - accuracy: 0.5327 - precision: 0.5327 - recall: 0.5327 - val_loss: 0.6911 - val_accuracy: 0.5938 - val_precision: 0.5938 - val_recall: 0.5938
# Epoch 147/150
# 24/24 [==============================] - 11s 454ms/step - loss: 0.6906 - accuracy: 0.5526 - precision: 0.5526 - recall: 0.5526 - val_loss: 0.6764 - val_accuracy: 0.5938 - val_precision: 0.5938 - val_recall: 0.5938
# Epoch 148/150
# 24/24 [==============================] - 11s 472ms/step - loss: 0.6895 - accuracy: 0.5495 - precision: 0.5495 - recall: 0.5495 - val_loss: 0.6834 - val_accuracy: 0.5729 - val_precision: 0.5729 - val_recall: 0.5729
# Epoch 149/150
# 24/24 [==============================] - 11s 465ms/step - loss: 0.6865 - accuracy: 0.5608 - precision: 0.5608 - recall: 0.5608 - val_loss: 0.6825 - val_accuracy: 0.5938 - val_precision: 0.5938 - val_recall: 0.5938
# Epoch 150/150
# 24/24 [==============================] - 11s 471ms/step - loss: 0.6898 - accuracy: 0.5453 - precision: 0.5453 - recall: 0.5453 - val_loss: 0.6862 - val_accuracy: 0.5625 - val_precision: 0.5625 - val_recall: 0.5625

# %% [markdown]
# ## Step 7. 결과 확인 및 시각화

# %%
fig, ax = plt.subplots(2, 2, figsize=(10, 10))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ## Step 8. 최종 Test dataset 검정하기

# %%
model = tf.keras.models.load_model("best_model_basic.h5")
loss, acc, prec, rec = model.evaluate(test_ds)
# Out:
# 4/4 [==============================] - 2s 97ms/step - loss: 0.6775 - accuracy: 0.6154 - precision: 0.6154 - recall: 0.6154

# %% [markdown]
# ## Discussion
